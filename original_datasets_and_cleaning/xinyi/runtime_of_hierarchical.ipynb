# %% [markdown]
# # Time

# %%
import time

import numpy as np
import pandas as pd
from sequenzo import *
from sequenzo.clustering import Cluster

# %% [markdown]
# ## Broad_df_5_years

# %%
# get dissimilarity distance matrix
df = pd.read_csv("D:/college/research/QiQi/sequenzo/files/sampled_data_sets/broad_data/sampled_5000_data.csv")   # 每次修改中间的 ‘5000’ 即可

_time = list(df.columns)[4:]

states = ['Non-computing', 'Non-technical computing', 'Technical computing']

df = df[['worker_id', 'C1', 'C2', 'C3', 'C4', 'C5']]

sequence_data = SequenceData(df, time_type="age", time=_time, id_col="worker_id", states=states)

diss = get_distance_matrix(sequence_data, method="OMspell", sm="TRATE", indel="auto")

diss
# Out:
# [>] SequenceData initialized successfully! Here's a summary:
# [>] Number of sequences: 5000
# [>] Min/Max sequence length: 5 / 5
# [>] Alphabet: ['Non-computing', 'Non-technical computing', 'Technical computing']
# [>] Processing 5000 sequences with 3 unique states.
# [>] Transition-based substitution-cost matrix (TRATE) initiated...
#   - Computing transition probabilities for: [Non-computing, Non-technical computing, Technical computing]
# [>] Indel cost generated.
#
# [>] Identified 85 unique spell sequences.
# [>] Sequence spell length: min/max = 1 / 4.
#
# [>] Starting Optimal Matching with spell(OMspell)...
# [>] Computing all pairwise distances...
# [>] Computed Successfully.
#                           tom-williams-9b982013b  emily-jacobs-b62a95237  \
# tom-williams-9b982013b                  0.000000                0.000000
# emily-jacobs-b62a95237                  0.000000                0.000000
# alok-maheshwari-5879243                 0.000000                0.000000
# harikarani                              0.000000                0.000000
# rasoolbabushaik                         0.000000                0.000000
# ...                                          ...                     ...
# alan-nguyen-873a2210                    0.000000                0.000000
# nicholas-andre-7a93b9246                0.000000                0.000000
# bidisha-dutta-2118a0125                 5.829745                5.829745
# rakesh-ranjan55                         5.829745                5.829745
# ronit-kumar-627173103                   0.000000                0.000000
#
#                           alok-maheshwari-5879243  harikarani  \
# tom-williams-9b982013b                   0.000000    0.000000
# emily-jacobs-b62a95237                   0.000000    0.000000
# alok-maheshwari-5879243                  0.000000    0.000000
# harikarani                               0.000000    0.000000
# rasoolbabushaik                          0.000000    0.000000
# ...                                           ...         ...
# alan-nguyen-873a2210                     0.000000    0.000000
# nicholas-andre-7a93b9246                 0.000000    0.000000
# bidisha-dutta-2118a0125                  5.829745    5.829745
# rakesh-ranjan55                          5.829745    5.829745
# ronit-kumar-627173103                    0.000000    0.000000
#
#                           rasoolbabushaik  daniel-burnett-82949740   jentyes  \
# tom-williams-9b982013b           0.000000                 1.468638  5.896683
# emily-jacobs-b62a95237           0.000000                 1.468638  5.896683
# alok-maheshwari-5879243          0.000000                 1.468638  5.896683
# harikarani                       0.000000                 1.468638  5.896683
# rasoolbabushaik                  0.000000                 1.468638  5.896683
# ...                                   ...                      ...       ...
# alan-nguyen-873a2210             0.000000                 1.468638  5.896683
# nicholas-andre-7a93b9246         0.000000                 1.468638  5.896683
# bidisha-dutta-2118a0125          5.829745                 4.468638  5.937276
# rakesh-ranjan55                  5.829745                 4.468638  5.937276
# ronit-kumar-627173103            0.000000                 1.468638  5.896683
#
#                           divya-n-30a08058  atri-rudra-b14289120  \
# tom-williams-9b982013b            5.829745              5.829745
# emily-jacobs-b62a95237            5.829745              5.829745
# alok-maheshwari-5879243           5.829745              5.829745
# harikarani                        5.829745              5.829745
# rasoolbabushaik                   5.829745              5.829745
# ...                                    ...                   ...
# alan-nguyen-873a2210              5.829745              5.829745
# nicholas-andre-7a93b9246          5.829745              5.829745
# bidisha-dutta-2118a0125           0.000000              0.000000
# rakesh-ranjan55                   0.000000              0.000000
# ronit-kumar-627173103             5.829745              5.829745
#
#                           rajani-kanta-swain-7024024a  ...  \
# tom-williams-9b982013b                       2.937276  ...
# emily-jacobs-b62a95237                       2.937276  ...
# alok-maheshwari-5879243                      2.937276  ...
# harikarani                                   2.937276  ...
# rasoolbabushaik                              2.937276  ...
# ...                                               ...  ...
# alan-nguyen-873a2210                         2.937276  ...
# nicholas-andre-7a93b9246                     2.937276  ...
# bidisha-dutta-2118a0125                      4.937276  ...
# rakesh-ranjan55                              4.937276  ...
# ronit-kumar-627173103                        2.937276  ...
#
#                           kyle-michel-6372b979  laura-waurio-50a69928  \
# tom-williams-9b982013b                5.829745               0.000000
# emily-jacobs-b62a95237                5.829745               0.000000
# alok-maheshwari-5879243               5.829745               0.000000
# harikarani                            5.829745               0.000000
# rasoolbabushaik                       5.829745               0.000000
# ...                                        ...                    ...
# alan-nguyen-873a2210                  5.829745               0.000000
# nicholas-andre-7a93b9246              5.829745               0.000000
# bidisha-dutta-2118a0125               0.000000               5.829745
# rakesh-ranjan55                       0.000000               5.829745
# ronit-kumar-627173103                 5.829745               0.000000
#
#                           stuti-agarwal-bba8a764  joekorchnak  \
# tom-williams-9b982013b                  0.000000     3.468638
# emily-jacobs-b62a95237                  0.000000     3.468638
# alok-maheshwari-5879243                 0.000000     3.468638
# harikarani                              0.000000     3.468638
# rasoolbabushaik                         0.000000     3.468638
# ...                                          ...          ...
# alan-nguyen-873a2210                    0.000000     3.468638
# nicholas-andre-7a93b9246                0.000000     3.468638
# bidisha-dutta-2118a0125                 5.829745     2.468638
# rakesh-ranjan55                         5.829745     2.468638
# ronit-kumar-627173103                   0.000000     3.468638
#
#                           narendra-akula-68659916a  alan-nguyen-873a2210  \
# tom-williams-9b982013b                    0.000000              0.000000
# emily-jacobs-b62a95237                    0.000000              0.000000
# alok-maheshwari-5879243                   0.000000              0.000000
# harikarani                                0.000000              0.000000
# rasoolbabushaik                           0.000000              0.000000
# ...                                            ...                   ...
# alan-nguyen-873a2210                      0.000000              0.000000
# nicholas-andre-7a93b9246                  0.000000              0.000000
# bidisha-dutta-2118a0125                   5.829745              5.829745
# rakesh-ranjan55                           5.829745              5.829745
# ronit-kumar-627173103                     0.000000              0.000000
#
#                           nicholas-andre-7a93b9246  bidisha-dutta-2118a0125  \
# tom-williams-9b982013b                    0.000000                 5.829745
# emily-jacobs-b62a95237                    0.000000                 5.829745
# alok-maheshwari-5879243                   0.000000                 5.829745
# harikarani                                0.000000                 5.829745
# rasoolbabushaik                           0.000000                 5.829745
# ...                                            ...                      ...
# alan-nguyen-873a2210                      0.000000                 5.829745
# nicholas-andre-7a93b9246                  0.000000                 5.829745
# bidisha-dutta-2118a0125                   5.829745                 0.000000
# rakesh-ranjan55                           5.829745                 0.000000
# ronit-kumar-627173103                     0.000000                 5.829745
#
#                           rakesh-ranjan55  ronit-kumar-627173103
# tom-williams-9b982013b           5.829745               0.000000
# emily-jacobs-b62a95237           5.829745               0.000000
# alok-maheshwari-5879243          5.829745               0.000000
# harikarani                       5.829745               0.000000
# rasoolbabushaik                  5.829745               0.000000
# ...                                   ...                    ...
# alan-nguyen-873a2210             5.829745               0.000000
# nicholas-andre-7a93b9246         5.829745               0.000000
# bidisha-dutta-2118a0125          0.000000               5.829745
# rakesh-ranjan55                  0.000000               5.829745
# ronit-kumar-627173103            5.829745               0.000000
#
# [5000 rows x 5000 columns]

# %%
# hierarchical clustering
start_time = time.time()
cluster = Cluster(diss, sequence_data.ids, clustering_method='ward')
print("step1 success.")
cluster.plot_dendrogram(xlabel="Countries", ylabel="Distance", save_as='dendrogram')
print("step2 success.")
end_time = time.time()
print(f"{end_time - start_time} seconds")
# Out:
# [>] Converting DataFrame to NumPy array...

# %% [markdown]
# ## Detailed_df_10_years

# %%
# get dissimilarity distance matrix
df = pd.read_csv('D:/college/research/QiQi/sequenzo/files/sampled_datasets/detailded_data/sampled_1000_data.csv')   # # 每次修改中间的 ‘1000’ 即可

_time = list(df.columns)[4:]
states = ['data', 'data & intensive math', 'hardware', 'research', 'software', 'software & hardware', 'support & test']
df = df[['worker_id', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'C10']]

data = SequenceData(df, time=_time, time_type="age", id_col="worker_id", states=states)
diss = get_distance_matrix(seqdata=data, method="OMspell", sm="TRATE", indel="auto")
# Out:
# [>] SequenceData initialized successfully! Here's a summary:
# [>] Number of sequences: 5000
# [>] Min/Max sequence length: 10 / 10
# [>] Alphabet: ['data', 'data & intensive math', 'hardware', 'research', 'software', 'software & hardware', 'support & test']
# [>] Processing 5000 sequences with 7 unique states.
# [>] Transition-based substitution-cost matrix (TRATE) initiated...
#   - Computing transition probabilities for: [data, data & intensive math, hardware, research, software, software & hardware, support & test]
# [>] Indel cost generated.
#
# [>] Identified 569 unique spell sequences.
# [>] Sequence spell length: min/max = 1 / 5.
#
# [>] Starting Optimal Matching with spell(OMspell)...
# [>] Computing all pairwise distances...
# [>] Computed Successfully.

# %%
# hierarchical clustering
start_time = time.time()
cluster = Cluster(diss, data.ids, clustering_method='ward')
cluster.plot_dendrogram(xlabel="Countries", ylabel="Distance", save_as='dendrogram')
end_time = time.time()
print(f"{end_time - start_time} seconds")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # hierarchical clustering
# ----> 2 start_time = time.time()
#       3 cluster = Cluster(diss, data.ids, clustering_method='ward')
#       4 cluster.plot_dendrogram(xlabel="Countries", ylabel="Distance", save_as='dendrogram')
#
# NameError: name 'time' is not defined

# %% [markdown]
# # Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 绘制折线图
def getPlot(data, save_path):
    df = pd.DataFrame(data)

    # Plot setup
    plt.figure(figsize=(10, 6))
    sns.set(style="whitegrid")

    # Plotting both R and Python data
    plt.plot(df['datasize'], df['R'], marker='o', label='R TraMineR', color='#5698C3', linewidth=2, markersize=8)
    plt.plot(df['datasize'], df['python'], marker='s', label='Python Sequenzo', color='#FCA104', linewidth=2,
             markersize=8)

    # Title and labels with more padding
    plt.xlabel('Data Size (in 10,000s)', fontsize=14, labelpad=35)
    plt.ylabel('Execution Time (seconds)', fontsize=14, labelpad=35)

    # Adding a legend with the specified caption
    plt.legend(title="Legend", title_fontsize='13', loc='upper left')

    # Adding a grid for better readability
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)

    # Adjusting layout to ensure there's no clipping of labels or titles
    plt.tight_layout()

    plt.savefig(save_path, dpi=300, bbox_inches='tight')

    plt.show()

# %%
# for Broad data
save_path = 'D:/college/research/QiQi/sequenzo/files/sampled_datasets/broad_data/output/hierarchical_clustering_runtime_vs_datasize.png'

RLCP = [1.4668, 2.9318, 5.4178, 7.1749, 13.5513, 17.7556]

data_broad = {
                'datasize': ['0.5', '1', '1.5', '2', '2.5', '3', '3.5', '4', '4.5', '5', '5.5', '6'],
                'python': [0.3002021312713623, 0.9247539043426514, 2.2009403705596924, 3.4316680431365967, 5.464114665985107, 6.9214935302734375, 9.47014832496643, 17.558588981628418, ],   # LCP!!!
                'R': [1.5168, 2.7445, 4.0915, 7.4630, 13.4019, 21.7187, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan],
             }

getPlot(data_broad, save_path)

# %%
# for Detailed data
save_path = 'D:/college/research/QiQi/sequenzo/files/output_runtime/detailed_LCP_runtime_vs_datasize.jpg'

RLCP = [0.6618, 1.1051, 2.5848, 5.1392, 8.0038, 13.7457, 19.3897]

data_detailed = {
                    'datasize': ['0.1', '0.5', '1', '1.5', '2', '2.5', '3', '3.5', '3.89'],
                    'python': [],   # RLCP
                    'R': [1.1814, 1.6463, 2.4667, 4.4902, 10.3714, 15.6479, 25.9570, np.nan, np.nan],
                }

getPlot(data_detailed, save_path)
